# %%
#importing the necessary libraries
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)
import chardet
import glob
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams["figure.figsize"] = [15, 10]
from bertopic import BERTopic
from umap import UMAP
import random
random.seed(42)

# %%
#avoid any stochastic behaviour in bertopic
umap_model = UMAP(n_neighbors=15, n_components=5, 
                  min_dist=0.0, metric='cosine', random_state=42)

# %%
# read all request files
pedidos_path = glob.glob("../data/20220219_Pedidos_csv_*")

files_list = []

for filename in pedidos_path:
    
    pedidos_file = pd.read_csv(filename,
                               sep=";",
                               quotechar="'",
                        header = None,
                        names=['IdPedido',
                              'ProtocoloPedido',
                              'Esfera',
                              'OrgaoDestinatario',
                              'Situacao',
                              'DataRegistro',
                              'ResumoSolicitacao',
                              'DetalhamentoSolicitacao',
                              'PrazoAtendimento',
                              'FoiProrrogado',
                              'FoiReencaminhado',
                              'FormaResposta',
                              'OrigemSolicitacao',
                              'IdSolicitante',
                              'AssuntoPedido',
                              'SubAssuntoPedido',
                              'Tag',
                              'DataResposta',
                              'Resposta',
                              'Decisao',
                              'EspecificacaoDecisao'],
                               keep_default_na=False,
                        encoding='UTF-16 LE')
    
    files_list.append(pedidos_file)

pedidos = pd.concat(files_list, axis=0, ignore_index=True)

# %%
#formatting date columns
pedidos['DataRegistro_formatted'] =  pd.to_datetime(pedidos.DataRegistro,errors='coerce', format="%d/%m/%Y")
pedidos['PrazoAtendimento_formatted'] =  pd.to_datetime(pedidos.PrazoAtendimento, errors='coerce',format="%d/%m/%Y")
pedidos['DataResposta_formatted'] =  pd.to_datetime(pedidos.DataResposta,errors='coerce', format="%d/%m/%Y")

# %%
pedidos['lgpd_flag'] = pedidos.Resposta.apply(lambda x: 'lgpd' in x or '13.709' in x or 'lpgd' in x)

# %%
pedidos['lgpd_flag'].sum()
# Out:
# 1679

# %%
pedidos_lgpd = pedidos[pedidos['lgpd_flag']]

# %%
pedidos_list = pedidos_lgpd.DetalhamentoSolicitacao.to_list()

# %%
topic_model_v1 = BERTopic(verbose=True, language='Portuguese', nr_topics="auto", umap_model=umap_model)

# %%
requests_topics, requests_probabilities = topic_model_v1.fit_transform(pedidos_list)
# Out:
# Batches:   0%|          | 0/53 [00:00<?, ?it/s]
# 2022-02-21 11:42:31,000 - BERTopic - Transformed documents to Embeddings
# 2022-02-21 11:42:37,935 - BERTopic - Reduced dimensionality with UMAP
# 2022-02-21 11:42:38,358 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# 2022-02-21 11:42:42,283 - BERTopic - Reduced number of topics from 29 to 19

# %%
topic_model_v1.get_topic_freq()
# Out:
#     Topic  Count
# 0       0    641
# 1      -1    275
# 2       1    238
# 3       2    136
# 4       3     65
# 5       4     43
# 6       5     39
# 7       6     28
# 8       7     24
# 9       8     23
# 10      9     22
# 11     10     21
# 12     11     20
# 13     12     20
# 14     13     20
# 15     14     20
# 16     15     16
# 17     16     14
# 18     17     14

# %%
pedidos_lgpd['requests_topics'] = requests_topics
pedidos_lgpd['requests_probabilities'] = requests_probabilities

# %%
for t in set(requests_topics):
    pedidos_lgpd.loc[pedidos_lgpd.requests_topics == t,
                              'requests_topics_top_words'] = \
    str([a_tuple[0] for a_tuple in topic_model_v1.get_topic(t)])[1:-1]

# %%
pedidos_lgpd[['requests_topics','requests_topics_top_words']].drop_duplicates().sort_values('requests_topics')
# Out:
#         requests_topics  \
# 99889                -1
# 63362                 0
# 127167                1
# 128095                2
# 190644                3
# 101258                4
# 188852                5
# 190325                6
# 161965                7
# 188572                8
# 197932                9
# 233657               10
# 105391               11
# 188430               12
# 121020               13
# 187783               14
# 247308               15
# 65957                16
# 188108               17
#
#                                                                                                 requests_topics_top_words
# 99889                                              'de', 'do', 'que', 'da', 'em', 'ao', 'no', 'processo', 'com', 'acesso'
# 63362                                                 'de', 'da', 'por', 'do', 'dados', 'que', 'em', 'para', 'data', 'os'
# 127167                            'processo', 'incra', 'acesso', 'sei', '54000', 'nº', 'ao', 'do', 'de', 'administrativo'
# 128095                                'meu', 'inss', 'não', 'que', 'extrato', 'saber', 'eu', 'do', 'receber', 'benefício'
# 190644                  'entrada', 'saída', 'registros', 'palácio', 'planalto', 'de', 'da', 'do', 'solicito', 'bolsonaro'
# 101258         'políticas', 'que', 'em', 'entrará', 'determinado', 'vigor', 'existem', 'positivo', 'possui', 'informação'
# 188852                     '54000', 'processo', '2021', 'andamento', '2020', 'saber', 'do', 'gostaria', '08', 'comercial'
# 190325                            'lgpd', 'tratamento', 'de', 'dados', 'ou', 'foi', 'adequação', 'pessoais', 'anpd', 'da'
# 161965                                  'dados', 'pessoais', 'meus', 'base', 'de', 'com', 'informação', 'dos', 'do', 'da'
# 188572                                'imbel', 'pistola', 'gc', 'md2', 'armamento', 'gostaria', '45', 'saber', 'da', 'de'
# 197932                 'cargo', 'empresa', 'benefícios', 'servidor', 'de', 'servidores', 'se', 'oferece', 'do', 'valores'
# 233657             'entidade', 'lgpd', 'órgão', 'encarregado', 'implantação', 'já', 'está', 'qual', 'implantou', 'ligado'
# 105391                                 'de', 'dados', 'software', 'da', 'lei', 'edital', 'sobre', 'proteção', 'que', 'no'
# 188430                        'pescadores', 'rgp', 'de', 'atividade', 'registro', 'pesca', 'pesqueira', 'da', 'com', 'do'
# 121020          'contrato', 'contratos', 'de', 'cópia', 'serviços', 'icj', 'odebrecht', 'aditivos', 'para', 'construtora'
# 187783  'geneticamente', '01245', 'liberação', 'planejada', 'processo', '2021', 'ctnbio', 'ambiente', 'de', 'protocolado'
# 247308                       'especifica', 'cbo', 'remuneração', 'rais', 'cbos', 'somente', 'total', 'sppt', 'ac', '2253'
# 65957              'protocolo', 'fluxo', 'procedimento', 'documentos', 'forma', 'qual', 'para', 'as', 'utilizado', 'pelo'
# 188108                         'vítima', 'violência', 'suspeito', 'de', '180', 'da', 'mulher', 'denúncias', 'do', 'faixa'

# %%
pedidos_respostas_list = pedidos_lgpd.Resposta.to_list()
topic_model_v2 = BERTopic(verbose=True, language='Portuguese', nr_topics="auto", umap_model=umap_model)

# %%
requests_topics, requests_probabilities = topic_model_v2.fit_transform(pedidos_respostas_list)
# Out:
# Batches:   0%|          | 0/53 [00:00<?, ?it/s]
# 2022-02-20 14:51:16,404 - BERTopic - Transformed documents to Embeddings
# 2022-02-20 14:51:23,079 - BERTopic - Reduced dimensionality with UMAP
# 2022-02-20 14:51:23,233 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# 2022-02-20 14:51:30,054 - BERTopic - Reduced number of topics from 54 to 31

# %%
topic_model_v2.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1    359
# 1       0    304
# 2       1    178
# 3       2    134
# 4       3    132
# 5       4     45
# 6       5     42
# 7       6     37
# 8       7     36
# 9       8     33
# 10      9     32
# 11     10     30
# 12     11     28
# 13     12     25
# 14     13     25
# 15     14     21
# 16     15     18
# 17     16     17
# 18     17     17
# 19     18     17
# 20     19     16
# 21     20     16
# 22     21     15
# 23     22     14
# 24     23     14
# 25     24     13
# 26     25     13
# 27     26     13
# 28     27     12
# 29     28     12
# 30     29     11

# %%
pedidos_lgpd['requests_topics_answers'] = requests_topics
pedidos_lgpd['requests_probabilities_answers'] = requests_probabilities

# %%
for t in set(requests_topics):
    pedidos_lgpd.loc[pedidos_lgpd.requests_topics_answers == t,
                              'requests_topics_top_words_answers'] = \
    str([a_tuple[0] for a_tuple in topic_model_v2.get_topic(t)])[1:-1]

# %%
pedidos_lgpd[['requests_topics_answers',
              'requests_topics_top_words_answers']].drop_duplicates().sort_values('requests_topics_answers')
# Out:
#         requests_topics_answers  \
# 63362                        -1
# 188117                        0
# 101258                        1
# 297990                        2
# 187872                        3
# 183844                        4
# 66934                         5
# 65822                         6
# 191727                        7
# 111649                        8
# 187783                        9
# 123706                       10
# 189446                       11
# 155751                       12
# 155693                       13
# 208464                       14
# 188430                       15
# 99889                        16
# 296606                       17
# 159090                       18
# 189592                       19
# 233663                       20
# 222715                       21
# 200019                       22
# 116669                       23
# 151127                       24
# 151107                       25
# 216298                       26
# 99068                        27
# 233657                       28
# 157343                       29
#
#                                                                                                    requests_topics_top_words_answers
# 63362                                                                'de', 'que', 'da', 'do', 'dados', 'em', 'ou', 'no', 'lei', 'se'
# 188117                                        'incra', 'br', 'do', 'acesso', 'link', 'sei', 'acessando', 'mail', 'cadastro', 'termo'
# 101258                                                         'de', 'dados', 'ou', 'que', 'da', 'em', 'do', 'pessoais', 'lei', 'os'
# 297990                           'casos', 'covid', '19', 'saude', 'síndrome', 'de', 'vigilância', 'saúde', 'ministério', 'influenza'
# 187872                         'inss', 'meu', 'central', 'telefone', 'inc', 'atendimento', '135', 'serviço', 'informações', 'criado'
# 183844                               'imbel', 'ouvidoria', 'da', 'de', 'que', 'manifestação', 'publicidade', 'com', 'trabalho', 'no'
# 66934                              'república', 'presidente', 'da', 'segurança', 'presidência', 'do', 'de', 'art', 'gabinete', 'que'
# 65822                                          'anpd', '2021', 'de', 'autoridade', 'proteção', 'da', '01', 'lgpd', 'que', 'nacional'
# 191727                    'república', 'presidente', 'segurança', 'da', 'presidência', 'do', 'vice', 'tratamento', 'art', 'gabinete'
# 111649                                   'inep', 'de', 'educacionais', 'que', 'da', 'do', 'informação', 'microdados', 'dos', 'ufrgs'
# 187783                    'respeitando', 'lei', 'comissão', 'coordenação', 'civil', 'de', '472', 'confidenciais', '279', 'perpassam'
# 123706                                                  'de', 'do', 'da', 'que', 'exército', 'ou', 'lei', 'art', 'pessoa', 'federal'
# 189446                             'srag', 'gripe', 'dados', 'epidemiológica', 'síndrome', 'sistema', 'vigilância', 'da', 'ms', 'de'
# 155751                                                             'md', 'defesa', 'de', 'sic', 'da', 'ao', 'por', 'do', 'que', 'ou'
# 155693                         'políticas', 'posic', 'em', 'comunicações', 'segurança', 'entrará', 'possui', 'positivo', 'que', 'da'
# 208464                          'srag', 'gripe', 'vigilância', 'da', 'síndrome', 'dados', 'epidemiológica', 'covid', 'sistema', '19'
# 188430                         'pesca', 'aquicultura', 'pescadores', 'mapa', 'registro', 'da', 'geral', 'de', 'monitoramento', 'com'
# 99889                             'humanos', 'direitos', 'mulher', 'denúncias', 'violência', 'família', 'da', 'de', 'mmfdh', 'dados'
# 296606                           'deg', 'coronavírus', 'direito', 'das', 'pessoais', 'pública', 'emergências', '979', 'ms', 'sigilo'
# 159090                         'aneel', 'elétrica', 'energia', 'regulação', 'agência', 'base', 'nosso', 'distribuição', 'data', 'de'
# 189592                'incapacidade', 'benefícios', 'por', 'inc', 'relativas', 'segurados', 'disposto', 'informações', 'no', 'podem'
# 233663                                'universidade', 'lgpd', 'sim', 'solicito', 'cópia', 'já', 'adequação', 'ufjf', 'ufpe', 'dados'
# 222715                                   'de', 'dados', 'que', 'datasus', 'da', 'saúde', 'sobre', 'mortalidade', 'informações', 'do'
# 200019                                             'indígena', 'sesai', 'se', 'saúde', 'indígenas', 'de', 'que', 'os', 'óbito', 'no'
# 116669       'anvisa', 'vacinas', 'vigimed', 'notificações', 'farmacovigilância', 'recebidos', 'sistema', 'sanitária', 'de', 'dados'
# 151127          'petrobras', 'resposta', 'transparência', 'contrato', 'anexo', 'depositada', 'sa', 'reafirmando', 'mail', 'petróleo'
# 151107                         'aeronáutica', 'da', 'comando', 'força', 'que', 'militares', 'comaer', 'centro', 'de', 'inteligência'
# 216298                             'saúde', 'covid', 'de', 'coronavírus', 'dados', 'saude', 'lei', 'casos', 'repasses', 'ministério'
# 99068   'inep', 'educacionais', 'microdados', 'estatísticas', 'variáveis', 'de', 'id_aluno', 'id_docente', 'caracteres', 'pesquisas'
# 233657                          'encarregado', 'entidade', 'lgpd', 'órgão', 'já', 'está', 'nomeado', 'fase', 'implantação', 'ufersa'
# 157343                               'imbel', 'com', 'ouvidoria', 'federal', 'isaloja', 'produtos', 'nosso', 'recursos', '79', 'tem'

# %%
pedidos_lgpd.to_csv('../data/pedidos_lgpd.csv',index=False)

# %%
topic_model_v2.get_topic(3)
# Out:
# [('inss', 0.09409252617362487),
#  ('meu', 0.0708985342603696),
#  ('central', 0.0455746086910481),
#  ('telefone', 0.042694756773734514),
#  ('inc', 0.04195539290749313),
#  ('atendimento', 0.040983334183268445),
#  ('135', 0.04019638739734234),
#  ('serviço', 0.039686261173998524),
#  ('informações', 0.039593154840608234),
#  ('criado', 0.031558265058684275)]
